# %%
# my first python code
print('hello world')
# Out:
# hello world

# %% [markdown]
# # here's a header
# ## here's a subheader
# ### here's a list
# 1. python
# 1. ruby
# 1. R
#
# here's a comment:
# >Markdown's awesome
#
# here's a code block:
#
# `print('hello world')`

# %%
a = 2
b = 3
c = a*b
print(c)
# Out:
# 6
